# %%
import os
os.getcwd()
# Out:
# '/Users/koreysansone/Projects'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SmartSales").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://mac.attlocal.net:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SmartSales</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Connect to the database the right way
import sqlite3

conn = sqlite3.connect('smart-store-koreysells/data/dw/smart_sales.db')
cursor = conn.cursor()

# List all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table in tables:
    print(table)

conn.close()
# Out:
# ('customers',)
# ('products',)
# ('sales',)

# %%
import sqlite3
import pandas as pd

# Connect to the database
conn = sqlite3.connect('smart_sales.db')

# Load Customers table
df_customers = pd.read_sql_query("SELECT * FROM customers", conn)

# Show first 10 customers
df_customers.head(10)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Projects/.venv/lib/python3.13/site-packages/pandas/io/sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: no such table: customers
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[17], line 8
#       5 conn = sqlite3.connect('smart_sales.db')
#       7 # Load Customers table
# ----> 8 df_customers = pd.read_sql_query("SELECT * FROM customers", conn)
#      10 # Show first 10 customers
#      11 df_customers.head(10)
#
# File ~/Projects/.venv/lib/python3.13/site-packages/pandas/io/sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
# ...

# %%
import sqlite3
import pandas as pd

# Connect to database
conn = sqlite3.connect('smart-store-koreysells/data/dw/smart_sales.db')

# Load and show Customers
df_customers = pd.read_sql_query("SELECT * FROM customers", conn)
display(df_customers.head(10))

# Load and show Products
df_products = pd.read_sql_query("SELECT * FROM products", conn)
display(df_products.head(10))

# Load and show Sales
df_sales = pd.read_sql_query("SELECT * FROM sales", conn)
display(df_sales.head(10))

# Close connection
conn.close()
# Out:
#   customer_id             name region   join_date miles_from_depot  \
# 0        1001    William White   East  11/11/2021             None
# 1        1002     Wylie Coyote   East   2/14/2023             None
# 2        1003        Dan Brown   West  10/19/2023             None
# 3        1004        Chewbacca   West   11/9/2022             None
# 4        1007    Susan Johnson  South   6/30/2023             None
# 5        1008       Tony Stark  North    5/1/2020             None
# 6        1009     Jason Bourne   West   12/1/2020             None
# 7        1011  Hermione Grager   East   12/9/2022             None
#
#   preferredcontactmethod  loyaltypoints
# 0                  Email           50.0
# 1                 Phon1e          100.0
# 2                  Email           75.0
# 3                 Phonfe           25.0
# 4                  Email          100.0
# 5                  Phone          300.0
# 6                  Email          250.0
# ...
